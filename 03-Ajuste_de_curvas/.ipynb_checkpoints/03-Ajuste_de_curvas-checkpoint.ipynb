# %% [markdown]
# # Ajuste de curvas por mínimos cuadrados

# %% [markdown]
# ## Introducción
#
# La gran mayoría de las fórmulas en la ciencia no pueden ser determinadas de forma teórica y debemos recurrir a relaciones empíricas en base a experimentos.

# %% [markdown]
# Por ejemplo, en mecánica de fluidos la fuerza de arrastre, $F_D$, es proporcional al cuadrado de la velocidad del flujo alrededor del cuerpo, $V$:

# %% [markdown]
# \begin{equation*}
# F_D = \frac{1}{2}\rho A C_D V^2
# \end{equation*}
#
# donde $\rho$ es la densidad del fluido, $A$ es el área proyectada en la dirección del flujo, y $C_D$ es el coeficiente de arrastre.

# %% [markdown]
# <img src="./images/drag_force_formula.png" width="250" align= center>

# %% [markdown]
# Aunque esta relación es válida para cualquier cuerpo, el valor de $C_D$ cambia dependiendo del objeto.

# %% [markdown]
# En la gran mayoría de los casos, este valor no se puede determinar de forma analítica, y debemos recurrir a ensayos en un túnel de viento para determinar la relación entre estas dos variables.
#
# <img src="./images/wind_tunnel.png" width="800" align= center>
#
# El valor de $C_D$ estará dado por la curva que mejor se ajuste a estos valores experimentales.

# %% [markdown]
# ### Ajuste vs. interpolación
# Dados los datos $(x_i, y_i)$, hay dos caminos para construir una función $y(x)$:
#
# <img src="./images/interpolacion_1D.png" width="300" align= center>

# %% [markdown]
# > Cuando los datos tienen ruido experimental, forzar la curva a pasar por *cada* punto reproduce el ruido, no la física. En esta unidad buscamos la **tendencia**: ajuste de curvas. La interpolación (datos *sin* ruido) es el tema de la Unidad 4.

# %% [markdown]
# ### Regresión lineal unidimensional

# %% [markdown]
# Consideremos el caso más simple, donde buscamos ajustar nuestros datos $x_i, y_i$ $(i = 1,2,\cdots,m)$ al modelo:
#
# \begin{equation*}
# y = a_0 + a_1x,
# \end{equation*}
#
# donde $a_0$ y $a_1$ son coeficientes que representan el intercepto y la pendiente, respectivamente.

# %% [markdown]
# **¿Cómo determinamos los coeficientes?**

# %% [markdown]
# Si intentamos determinar $a_0$ y $a_1$ mediante un sistema de ecuaciones:
#
# \begin{align*}
# y_1 &= a_0 + a_1 x_1 \\
# y_2 &= a_0 + a_1 x_2 \\
# \vdots &= \vdots \\
# y_m &= a_0 + a_1 x_m
# \end{align*}

# %% [markdown]
# Notamos que tenemos un sistema de 2 incógnitas y $m$ ecuaciones linealmente independientes. Es decir, **no existe una solución única a este problema.**

# %% [markdown]
# Lo que debemos hacer, entonces, es encontrar los valores de $a_0$ y $a_1$ que minimizan el error.

# %% [markdown]
# Particularmente, buscamos minimizar la expresión
#
# \begin{equation}
# S_r = \sum_{i=1}^m \left(y_i - a_0 - a_1 x_i\right)^2
# \end{equation}
#
# donde $i = 1,...,m$ son los datos de la muestra considerando un total de $m$ datos.

# %% [markdown]
# Este criterio se denomina **ajuste por mínimos cuadrados.**

# %% [markdown]
# En la siguiente animación, mueve $a_0$ y $a_1$ para hacer el error $S_r$ lo más pequeño posible. Cada residuo se dibuja como un cuadrado: **su área total es $S_r$.**

# %%
from pathlib import Path
from IPython.display import HTML

HTML(Path('interactive/A1_cazador_de_rectas.html').read_text(encoding='utf-8'))
# Out:
# <meta charset="utf-8">
# <style>
# #cdr-app{--cdr-tinta:#1a2733; --cdr-suave:#5d6b78; --cdr-linea:#d8dee4; --cdr-panel:#f6f8fa;
#          --cdr-c1:#1f77b4; --cdr-c2:#ff7f0e; --cdr-rojo:#d62728; --cdr-acento:#00afd8;
#          --cdr-verde:#1c7a3e;
#          width:100%; max-width:min(808px, 94vw); margin:0; padding:4px 2px;
#          color:var(--cdr-tinta); background:transparent;
#          font-family:"Segoe UI",Calibri,system-ui,sans-serif; font-size:15px; line-height:1.45}
# #cdr-app *{box-sizing:border-box}
# #cdr-app .cdr-wrap{display:flex;gap:1.05em;align-items:flex-start;flex-wrap:wrap}
# #cdr-app .cdr-izq{flex:3 1 264px;min-width:0;max-width:448px}
# #cdr-app .cdr-der{flex:2 1 250px;min-width:0;font-size:0.85em}
# #cdr-app svg{width:100%;height:auto;display:block;background:#fff;
#              border:1px solid var(--cdr-linea);border-radius:0.55em}
# #cdr-app .cdr-ctrl{background:var(--cdr-panel);border:1px solid var(--cdr-linea);
# ...

# %% [markdown]
# ### Ajuste por mínimos cuadrados paso a paso
# Lo que recién buscamos moviendo deslizadores, el cálculo lo entrega de forma exacta.
#
# Primero, para buscar el mínimo de $S_r$ aplicamos la derivada respecto a sus variables, es decir, $a_0$ y $a_1$
#
# \begin{align*}
# \frac{\partial S_r}{\partial a_0} &= -2 \sum \left(y_i - a_0 - a_1 x_i\right)
# \\
# \frac{\partial S_r}{\partial a_1} &= -2 \sum \left[\left(y_i - a_0 - a_1 x_i\right)x_i\right]
# \end{align*}

# %% [markdown]
# El mínimo está dado cuando ambas derivadas son $0$.
#
# \begin{align*}
# 0 &= \sum y_i - a_0\sum 1 - a_1\sum x_i
# \\
# 0 &=  \sum y_ix_i - a_0\sum x_i - a_1 \sum x_i^2
# \end{align*}

# %% [markdown]
# El resultado podemos expresarlo como un sistema de ecuaciones lineales:
#
# \begin{equation*}
# \begin{bmatrix}
# m & \sum x_i \\
# \sum x_i & \sum x_i^2
# \end{bmatrix}
# \left[\begin{array}{c} a_0 \\a_1\end{array}\right] =
# \left[\begin{array}{c} \sum y_i \\\sum x_iy_i \end{array}\right]
# \end{equation*}
#
# La solución de este sistema nos entregará los valores de $a_0$ y $a_1$

# %% [markdown]
# Consideremos los datos del problema del túnel de viento
#
# |$V$ (m/s) | 10 | 20 | 30 | 40 | 50 | 60 | 70 | 80 |
# |:--------:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|:--:|
# |$F$ (N)   | 25 | 70 |380 |550 |610 |1220|830 |1450|

# %%
import numpy as np

# creamos un arreglo con los datos tabulados
xi = np.array([ 10, 20,  30,  40,  50,   60,  70,  80])  # velocidad (m/s)
yi = np.array([ 25, 70, 380, 550, 610, 1220, 830, 1450]) # fuerza de arrastre (N)

# construimos un sistema Ax = b
m = len(xi)
A = np.array([[   m     ,  np.sum(xi)  ],
              [np.sum(xi), np.sum(xi**2)]])

b = np.array([np.sum(yi),
              np.sum(yi*xi)])

# resolvemos el sistema
a = np.linalg.solve(A,b) 
print(f'Modelo lineal: \n y = {a[0]:.3f} + {a[1]:.3f}*x')
# Out:
# Modelo lineal:
#  y = -234.286 + 19.470*x

# %%
import matplotlib.pyplot as plt

# formato del lienzo
plt.rcParams.update({'font.size': 10}) # tamaño de fuente
plt.figure(figsize = (5,3))            # tamaño del lienzo

# ploteamos nuestro resultado
y = lambda x: a[0] + a[1]*x # creamos una función con el modelo de ajuste
x = np.linspace(0,85,100)   # creamos un arreglo para ploteo

plt.plot(xi, yi, 'ob',label = 'xi, yi')                             # gráfico con los datos tabulados
plt.plot(x, y(x), '-r', label = 'y = %.2f + %.2fx' % (a[0], a[1]))  # gráfico del modelo
plt.xlabel('Velocidad del viento, $V$ (m/s)')                       # etiqueta eje x
plt.ylabel('Fuerza de arrastre, $F$ (N)')                           # etiqueta eje y
plt.legend()                                                        # incluir leyenda
plt.show()                                                          # mostrar gráfico

# %% [markdown]
# ### ¿Por qué el error *cuadrático*?

# %% [markdown]
# Nada nos obliga a medir el error con cuadrados. Por ejemplo, otros criterios razonables:
#
# - Minimizar error absoluto $\min \sum_i |e_i|$
# - Minimizar error máximo $\min \max_i |e_i|$
# - Minimizar error cuadrático $\min \sum_i e_i^2$
#
# donde $e_i = y_i - y(x_i)$.

# %% [markdown]
# Cada criterio elige una recta distinta: **el criterio es parte del modelo** (pruébalo con el botón $\Sigma|e_i|$ de la animación anterior).
#
# <img src="./images/comparacion_criterios.png" width="400" align= center>

# %% [markdown]
# Sin embargo, el criterio $\min \sum_i e_i^2$ ofrece una curva que no es sesgada por los outliers (minimax) ni se sobreajusta demasiado ($\min \sum_i |e_i|$). Además, ofrece otras ventajas, entre ellas el hecho de que se obtiene una línea única para cierto conjunto de datos o que la ponderación "al cuadrado" castiga aquellos datos que se alejan demasiado de la estimación (más información en las referencias).

# %% [markdown]
# Más allá de las ventajas, la justificación de los cuadrados viene de la estadística. Si el error experimental es **gaussiano**, cada dato es una "tirada" aleatoria centrada en el modelo:

# %% [markdown]
# <img src="./images/mle_gauss.png" width="400" align= center>

# %% [markdown]
# **Mínimos cuadrados no es una convención arbitraria: es el estimador de máxima verosimilitud cuando el ruido es gaussiano**, donde la verosimilitud define la probabilidad de que el conjunto de datos observado haya sido generado por el modelo bajo dichos parámetros

# %% [markdown]
# > La *pérdida cuadrática* que minimizan los modelos de regresión en *machine learning* es exactamente este criterio.

# %% [markdown]
# ### Cuantificación del error

# %% [markdown]
# Para cuantificar la calidad de nuestro modelo utilizaremos el **coeficiente de determinación, $r^2$:**
#
# \begin{equation}
# r^2 = \frac{S_t - S_r}{S_t}
# \end{equation}
#
# donde
# - $S_r =  \sum\left[y_i - y(x_i)\right]^2$ es el error del modelo de regresión ($y(x) = a_0 + a_1x$, en este caso)
#
# - $S_t = \sum\left(y_i - \bar{y}\right)^2$ es la **suma total de cuadrados**: la dispersión de los datos respecto a la media $\bar{y}$ (el error del modelo más simple posible, $y=\bar{y}$).

# %% [markdown]
# >El coeficiente de determinación nos permite cuantificar la calidad de nuestro modelo para representar una muestra, en comparación con la media $\bar{y}$.

# %% [markdown]
# En Python, este valor está dado por la función `r2_score` de la librería `scikit-learn`

# %%
from sklearn.metrics import r2_score 
print('coef. de determinación')
print(f'r2 = {r2_score(yi, y(xi)):.4f}')
# Out:
# coef. de determinación
# r2 = 0.8805

# %% [markdown]
# > El resultado indica que el modelo lineal explica un 88.05% de la varianza de los datos

# %% [markdown]
# >**Nota.** `r2_score(yi, y(xi))` requiere dos arreglos de iguales dimensiones.

# %% [markdown]
# ### Linealización de funciones no lineales
# Existen algunos modelos no lineales comunes en ingeniería que pueden ser linealizados para luego realizar ajuste por mínimos cuadrados.

# %% [markdown]
# Algunos ejemplos son:
# - **modelo exponencial**
#
# \begin{equation*}
# y = \alpha e^{\beta x} \Rightarrow \ln(y) = \ln(\alpha) + \beta x
# \end{equation*}
#
# - **modelo de potencia**
#
# \begin{equation*}
# y = \alpha x^{\beta} \Rightarrow \log(y) = \log(\alpha) + \beta \log (x)
# \end{equation*}
#
# - **modelo de tasa de crecimiento de saturación**
#
# \begin{equation*}
# y = \alpha \frac{x}{\beta + x} \Rightarrow
# \frac{1}{y} = \frac{1}{\alpha} +\frac{\beta}{\alpha}\frac{1}{x}
# \end{equation*}

# %% [markdown]
# <img src="./images/linealization.png" width="800" align= center>

# %% [markdown]
# > **Nota.** Para el modelo de potencia puede usarse "$\log$" o "$\ln$". **Los coeficientes del modelo linealizado serán diferentes**, pero al aplicar la inversa correcta ($10^x$ o $e^x$) **el modelo original recuperado es el mismo.**

# %% [markdown]
# Analicemos el ejemplo anterior, ahora ajustando los datos al modelo de potencia $y = \alpha x^{\beta}$

# %% [markdown]
# Primero, aplicaremos un modelo de ajuste de la forma: $\ln(y) = a_0 + a_1\ln(x)$.

# %%
import numpy as np
from numpy import log # en Python, log(x) = ln(x)
xi = np.array([ 10, 20,  30,  40,  50,   60,  70,  80])
yi = np.array([ 25, 70, 380, 550, 610, 1220, 830, 1450])

# linealizamos las variables
log_xi = log(xi)
log_yi = log(yi)

# construimos un sistema Ax = b
m = len(xi)   # número de datos
A = np.array([[   m          ,  np.sum(log_xi)  ],
              [np.sum(log_xi), np.sum(log_xi**2)]])

b = np.array([np.sum(log_yi),
              np.sum(log_yi*log_xi)])

# resolvemos el sistema
a = np.linalg.solve(A,b) 
print(f'Modelo linealizado: \n ln(y) = {a[0]:.3f} + {a[1]:.3f}*ln(x)')
# Out:
# Modelo linealizado:
#  ln(y) = -1.294 + 1.984*ln(x)

# %% [markdown]
# Para retornar al modelo original, aplicamos
#
# \begin{equation*}
# y = e^{\left(a_0+a_1\ln x\right)} = e^{a_0} x^{a_1} = \alpha x ^\beta
# \end{equation*}

# %% [markdown]
# donde deducimos que $\alpha = e^{a_0}$ y $\beta = a_1$.

# %%
alpha = np.exp(a[0])
beta  = a[1]

print('Modelo no lineal')
print(f'y = {alpha:.3f}*x^{beta:.3f}')
# Out:
# Modelo no lineal
# y = 0.274*x^1.984

# %% [markdown]
# Graficamos el resultado con el modelo no lineal $y = \alpha x^{\beta}$

# %%
plt.figure(figsize = (5,4))            # tamaño del lienzo

# graficamos nuestro resultado
y = lambda x: alpha*x**beta     # función con el modelo no lineal
x = np.linspace(1,85,100)       # creamos un arreglo para ploteo

plt.plot(xi, yi, 'bo',label = 'xi, yi')                                 # gráfico con los datos tabulados
plt.plot(x, y(x), '-r', label = r'$y = %.3fx^{%.3f}$' % (alpha, beta))  # gráfico del modelo
plt.xlabel('Velocidad del viento, $V$ (m/s)')                           # etiqueta eje x
plt.ylabel('Fuerza de arrastre, $F$ (N)')                               # etiqueta eje y
plt.legend()                                                            # incluir leyenda
plt.show()                                                              # mostrar gráfico

# %% [markdown]
# Analizamos la calidad del modelo

# %%
# analizamos la calidad del modelo
from sklearn.metrics import r2_score 

print('coef. de determinación')
print(f'r2 = {r2_score(yi, y(xi)):.4f}')
# Out:
# coef. de determinación
# r2 = 0.8088

# %% [markdown]
# > El resultado indica que el modelo de potencia explica un 80.88% de la varianza de los datos

# %% [markdown]
# El coeficiente de determinación para el modelo no lineal ($r^2=80.88\%$) es menor que para el modelo lineal ($r^2=88.05\%$). Sin embargo, el modelo no lineal se ajusta mejor al modelo físico (por ejemplo, $F = 0$ para $v = 0$).

# %% [markdown]
# Por lo tanto, el modelo más adecuado para los datos es el de potencia:
#
# \begin{equation*}
# y = 0.274 x^{1.984},
# \end{equation*}

# %% [markdown]
# ## Generalización para modelos lineales

# %% [markdown]
# El procedimiento se extiende a cualquier modelo **lineal en los coeficientes**:
#
# \begin{equation*}
# y = a_0\,\phi_0(\mathbf{x}) + a_1\,\phi_1(\mathbf{x}) + \cdots + a_n\,\phi_n(\mathbf{x})
# \end{equation*}
#
# donde las $\phi_k$ son **funciones base** conocidas y $\mathbf{x} = x_1, x_2, x_3, \ldots$ son las variables independientes del problema.

# %% [markdown]
# Por ejemplo:
# - recta: $\phi_0 = 1$, $\phi_1 = x$
# - polinomio: $\phi_k = x^k$
# - multivariable: $\phi_0 = 1$, $\phi_1 = x_1$, $\phi_2 = x_2$
# - incluso $\sin(x)$, $\cos(x)$, $e^{-x}$, ... — lo que importa es que $y$ sea **lineal en los $a_k$**

# %% [markdown]
# Evaluando el modelo en los $m$ datos, el sistema sobredeterminado del inicio se escribe:
#
# \begin{equation*}
# \underbrace{\begin{bmatrix}
# \phi_0(\mathbf{x}_1) & \phi_1(\mathbf{x}_1) & \cdots & \phi_n(\mathbf{x}_1)\\
# \phi_0(\mathbf{x}_2) & \phi_1(\mathbf{x}_2) & \cdots & \phi_n(\mathbf{x}_2)\\
# \vdots & \vdots &  & \vdots\\
# \phi_0(\mathbf{x}_m) & \phi_1(\mathbf{x}_m) & \cdots & \phi_n(\mathbf{x}_m)
# \end{bmatrix}}_{Z\;(m\times (n+1))}
# \begin{bmatrix} a_0\\ a_1\\ \vdots\\ a_n \end{bmatrix}
# \approx
# \begin{bmatrix} y_1\\ y_2\\ \vdots\\ y_m \end{bmatrix}
# \end{equation*}
#
# donde $Z$ se denomina **matriz de diseño** y $\mathbf{x}_i = x_1^i, x_2^i, x_3^i,\ldots$ son los datos de la muestra $i$.

# %% [markdown]
# La solución de mínimos cuadrados está dada por las **ecuaciones normales**:
#
# \begin{equation*}
# Z^TZ\,\mathbf{a} = Z^T\mathbf{y}
# \end{equation*}
#
# un sistema lineal de $(n+1)$ ecuaciones, como los de la Unidad 2.

# %% [markdown]
# > El sistema $2\times2$ que derivamos para la recta es exactamente $Z^TZ\,\mathbf{a} = Z^T\mathbf{y}$ con $Z = [\,\mathbf{1}\;\; \mathbf{x}\,]$. Ya no necesitamos derivar caso a caso: **basta elegir las columnas de $Z$.**

# %% [markdown]
# En el caso del modelo multivariable $y = a_0 + a_1x_1 + a_2x_2$ (columnas $1, x_1, x_2$), mínimos cuadrados determina el plano que minimiza el error cuadrático:
#
# <img src="./images/2D_plane.png" width="350" align= center>

# %% [markdown]
# ### En Python: `numpy.linalg.lstsq`
# Construimos $Z$ con las funciones base evaluadas en los datos y resolvemos. Por ejemplo, para el modelo cuadrático $y = a_0 + a_1x + a_2x^2$:

# %%
import numpy as np

xi = np.array([ 10, 20,  30,  40,  50,   60,  70,  80])
yi = np.array([ 25, 70, 380, 550, 610, 1220, 830, 1450])

# matriz de diseño: columnas 1, x, x^2
Z = np.column_stack([xi**0, xi, xi**2])

# solución de mínimos cuadrados
a = np.linalg.lstsq(Z, yi, rcond=None)[0]
print('Modelo cuadrático:')
print(f'y = {a[0]:.3f} + {a[1]:.3f}*x + {a[2]:.5f}*x^2')
# Out:
# Modelo cuadrático:
# y = -178.482 + 16.122*x + 0.03720*x^2

# %% [markdown]
# > `lstsq` no arma $Z^TZ$ explícitamente: usa métodos numéricamente más estables (Numerical Recipes §15.4). Funciona para **cualquier** modelo lineal en los coeficientes, con cualquier número de variables.

# %% [markdown]
# ## Funciones de ajuste en Python
#
# Es importante mencionar que en materia de modelos de ajuste la librería más adecuada es `scikit-learn`. La librería, sin embargo, puede ser demasiado compleja para modelos lineales simples.

# %% [markdown]
# A continuación, dos atajos prácticos: `numpy.polyfit` (polinomios univariables) y `scipy.optimize.curve_fit` (modelos no lineales).

# %% [markdown]
# ### Modelo polinomial unidimensional (`numpy.polyfit`)
# Esta función está específicamente diseñada para modelos polinomiales de una dimensión, es decir, $y = a_0 + a_1x +a_2x^2+...a_nx^n$

# %% [markdown]
# Por ejemplo, para generar un modelo en base a un polinomio de orden 2,
# ```python
# a = numpy.polyfit(xi,yi,2) # coeficientes a0, a1, a2, ...
# ```
# donde $a_0=$ `a[2]`, $a_1=$ `a[1]`, $a_2=$ `a[0]`

# %% [markdown]
# Tal como indica la [documentación oficial](https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html), **los coeficientes de `polyfit` están ordenados de mayor potencia a menor potencia.**
#
# <img src="./images/polyfit_doc.png" width="800" align= center>

# %% [markdown]
# Para evitar confusiones con el orden de los coeficientes, **se recomienda utilizar `numpy.polyval(a,x)`, que genera una función en base al modelo determinado**, donde `x` es un valor arbitrario y `a` son los coeficientes determinados por `polyfit`.
# ```python
# y = numpy.polyval(a,x) # función en base al modelo y(x) = a0 + a1*x + ... am*x^m
# ```

# %% [markdown]
# Analicemos el uso de `polyfit` y `polyval` con el ejemplo del túnel de viento

# %%
import numpy as np

# construimos el modelo
xi = np.array([ 10, 20,  30,  40,  50,   60,  70,  80])
yi = np.array([ 25, 70, 380, 550, 610, 1220, 830, 1450])

# Aplicamos modelo polinomial con polyfit
a = np.polyfit(xi,yi,2)
print('Modelo polinomial:')
print(f'y = {a[2]:.3f} + {a[1]:.3f}*x + {a[0]:.3f}*x^2')

# evaluamos polinomio de ajuste con polyval
x0 = 34 # valor de prueba
print(f'y({x0:.3f}) = {np.polyval(a, x0):.3f}')
# Out:
# Modelo polinomial:
# y = -178.482 + 16.122*x + 0.037*x^2
# y(34.000) = 412.673

# %% [markdown]
# Graficamos la solución con `polyval`:

# %%
plt.figure(figsize = (5,4))            # tamaño del lienzo

# graficamos nuestro resultado
x = np.linspace(1,85,100)       # creamos un arreglo para ploteo

plt.plot(xi, yi, 'bo',label = 'xi, yi')                # gráfico con los datos tabulados
plt.plot(x, np.polyval(a,x), '-r', label = 'polyfit')  # gráfico del modelo
plt.xlabel('Velocidad del viento, $V$ (m/s)')          # etiqueta eje x
plt.ylabel('Fuerza de arrastre, $F$ (N)')              # etiqueta eje y
plt.legend()                                           # incluir leyenda
plt.show()                                             # mostrar gráfico

# %%
# analizamos la calidad del modelo
from sklearn.metrics import r2_score 

print('coef. de determinación')
print(f'r2 = {r2_score(yi, np.polyval(a, xi)):.4f}')
# Out:
# coef. de determinación
# r2 = 0.8818

# %% [markdown]
# Notar que el gráfico del modelo muestra una tendencia aproximadamente lineal.

# %% [markdown]
# Esto es interesante, porque al incluir el término $a_2x^2$ en nuestro modelo lineal, $a_0 + a_1x$, esperábamos un mejor ajuste con el modelo físico $F_D = \frac{1}{2}\rho A C_D V^2$.

# %% [markdown]
# Sin embargo, **la tendencia del método es minimizar el error (en otras palabras, mejorar $r^2$).** Esto significa que el método va a forzar una curva lineal, aunque esta no corresponda a la física del problema.

# %% [markdown]
# ### `scipy.optimize.curve_fit` (regresión no lineal)
# Esta función, parte del módulo `optimize` de la librería `scipy`, **utiliza un método iterativo para minimizar el error cuadrático**. La función `curve_fit` puede ser utilizada para cualquier tipo de modelo, lineal o no lineal, unidimensional o multidimensional.

# %% [markdown]
# > **Nota** Para más información de `curve_fit`, revisar [documentación en línea](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html)

# %% [markdown]
# Para usar `curve_fit` primero debemos crear el modelo de ajuste en formato de función, por ejemplo para $y = \alpha x^\beta$:
# ```python
# def model(x,a,b):
#     y = a*x**b
#     return y
# ```

# %% [markdown]
# > El primer argumento de la función, `x`, *siempre debe ser la variable independiente*. Los parámetros de ajuste, `a` y `b`, van indicados en los argumentos siguientes.

# %% [markdown]
# Luego, llamamos a `curve_fit` usando el modelo de ajuste y la serie de datos $x_i, y_i$ como argumentos:
# ``` python
# coef = curve_fit(model, xdata = xi, ydata = yi)[0]
# a = coef[0] # parámetro alfa
# b = coef[1] # parámetro beta
# ```

# %% [markdown]
# > El índice `[0]` al final de `curve_fit` indica que necesitamos solo el primer *output*, el cual llamamos `coef`. Esta variable viene en formato de arreglo numpy (*ndarray*), donde el orden de los coeficientes corresponde al orden de `a` y `b` en `model`.

# %% [markdown]
# Por ejemplo, ajustemos los datos al modelo $y=\alpha x^\beta$

# %%
import numpy as np
from scipy.optimize import curve_fit

xi = np.array([ 10, 20,  30,  40,  50,   60,  70,  80])
yi = np.array([ 25, 70, 380, 550, 610, 1220, 830, 1450])

# creamos nuestro modelo de ajuste en formato de función
def model(x,a,b):
    y = a*x**b
    return y

# usamos curve_fit para determinar el valor de los parámetros a y b
coef = curve_fit(model, xdata = xi, ydata = yi)[0] # extraemos el primer output del modelo
a = coef[0] # parámetro alfa
b = coef[1] # parámetro beta

print('Modelo no lineal')
print(f'y = {a:.3f}*x^{b:.3f}')
# Out:
# Modelo no lineal
# y = 2.538*x^1.436

# %%
plt.figure(figsize = (5,4))            # tamaño del lienzo

# graficamos nuestro resultado
x = np.linspace(1,85,100)       # creamos un arreglo para ploteo

plt.plot(xi, yi, 'bo',label = 'xi, yi')                                 # gráfico con los datos tabulados
plt.plot(x, model(x,a,b), '-r', label = r'$y = %.3fx^{%.3f}$' % (a, b)) # gráfico del modelo
plt.xlabel('Velocidad del viento, $V$ (m/s)')                           # etiqueta eje x
plt.ylabel('Fuerza de arrastre, $F$ (N)')                               # etiqueta eje y
plt.legend()                                                            # incluir leyenda
plt.show()                                                              # mostrar gráfico

# %% [markdown]
# Notar que los coeficientes de este modelo son diferentes a los que determinamos mediante regresión lineal en la función linealizada.
#
# \begin{equation*}
# y = 0.274x^{1.984}\quad\left(r^2=80.88\%\right)
# \end{equation*}

# %% [markdown]
# Esto es debido a que la regresión no lineal busca minimizar el error
#
# \begin{equation*}
# S_r = \sum_{i=1}^m (f_\mathrm{nl}(x_i) - y_i)^2,
# \end{equation*}
#
# de forma iterativa.
#
# Así, `curve_fit` permite buscar soluciones con valores $r^2$ más cercanos a $1$ que no son accesibles para el modelo lineal

# %% [markdown]
# En efecto, si analizamos el coeficiente de determinación del modelo generado por `curve_fit`:

# %%
from sklearn.metrics import r2_score 
print('coef. de determinación')
print(f'r2 = {r2_score(yi, model(xi, a, b)):.4f}')
# Out:
# coef. de determinación
# r2 = 0.8769

# %% [markdown]
# > Para un modelo *lineal* en los coeficientes, `curve_fit`, `lstsq` y `polyfit` entregan **el mismo resultado**: todos minimizan el mismo $S_r$.

# %% [markdown]
# ## Del ajuste de curvas al *machine learning*
# Todo lo que hicimos en esta unidad sigue un esquema universal:
#
# \begin{equation*}
# \textbf{modelo con parámetros} \;\longrightarrow\; \textbf{función de pérdida} \;\longrightarrow\; \textbf{optimización}
# \end{equation*}

# %% [markdown]
# | | modelo | parámetros | pérdida | optimización |
# |---|---|:--:|:--:|---|
# | regresión lineal | $a_0 + a_1x$ | 2 | $\sum e_i^2$ | ecuaciones normales (exacta) |
# | `curve_fit` | $\alpha x^\beta$ | 2 | $\sum e_i^2$ | iterativa (Levenberg–Marquardt) |
# | red neuronal | composición de funciones | $10^6$–$10^{12}$ | $\sum e_i^2$ (u otra) | descenso de gradiente |
#
# **Cambia el modelo y la escala; el esquema es el mismo.**

# %% [markdown]
# ### ¿Por qué a veces hay fórmula y a veces hay que iterar?
# Para modelos lineales, la superficie de error es un **paraboloide**: un único valle y, por lo tanto, un **único mínimo**.

# %% [markdown]
# <img src="./images/error_surface.png" width="500" align= center>

# %% [markdown]
# Para modelos **no lineales** la superficie se deforma: puede tener varios valles y zonas planas. No existe fórmula cerrada. La alternativa: **caminar cuesta abajo.**

# %% [markdown]
# ### Descenso de gradiente
# Desde un punto de partida, avanzar repetidamente en la dirección de máxima bajada:
#
# \begin{equation*}
# \mathbf{a}_{k+1} = \mathbf{a}_k - \eta\,\nabla S_r(\mathbf{a}_k)
# \end{equation*}
#
# donde $\eta$ es la **tasa de aprendizaje** (el tamaño del paso).

# %%
HTML(Path('interactive/A2_descenso_gradiente.html').read_text(encoding='utf-8'))
# Out:
# <meta charset="utf-8">
# <style>
# #dgr-app{--dgr-tinta:#1a2733; --dgr-suave:#5d6b78; --dgr-linea:#d8dee4; --dgr-panel:#f6f8fa;
#          --dgr-c1:#1f77b4; --dgr-c2:#ff7f0e; --dgr-rojo:#d62728; --dgr-acento:#00afd8;
#          --dgr-verde:#1c7a3e;
#          width:100%; max-width:min(800px, 94vw); margin:0; padding:4px 2px;
#          color:var(--dgr-tinta); background:transparent;
#          font-family:"Segoe UI",Calibri,system-ui,sans-serif; font-size:15px; line-height:1.45}
# #dgr-app *{box-sizing:border-box}
# #dgr-app .dgr-wrap{display:flex;gap:1.05em;align-items:flex-start;flex-wrap:wrap}
# #dgr-app .dgr-izq{flex:3 1 304px;min-width:0;max-width:480px}
# #dgr-app .dgr-der{flex:2 1 235px;min-width:0;font-size:0.85em}
# #dgr-app svg{width:100%;height:auto;display:block;background:#fff;
#              border:1px solid var(--dgr-linea);border-radius:0.55em}
# #dgr-app .dgr-ctrl{background:var(--dgr-panel);border:1px solid var(--dgr-linea);
# ...

# %% [markdown]
# > *Entrenar* una red neuronal es este mismo bucle, con millones de parámetros. Los problemas que vimos —divergencia, mínimos locales, sensibilidad al punto de partida— son los mismos que enfrenta el *machine learning* a gran escala.

# %% [markdown]
# ### En el fondo, todo es buscar una raíz
# Minimizar $S_r$ es imponer que **todas** sus derivadas se anulen:
#
# \begin{equation*}
# \nabla S_r(\mathbf{a}) =
# \left[\frac{\partial S_r}{\partial a_0},\;\frac{\partial S_r}{\partial a_1},\;\cdots,\;\frac{\partial S_r}{\partial a_n}\right]^T = \mathbf{0}
# \end{equation*}

# %% [markdown]
# > Un sistema de $n+1$ ecuaciones con $n+1$ incógnitas. **Ajustar una curva es, en el fondo, resolver este sistema: un problema de búsqueda de raíces.**

# %% [markdown]
# Lo que cambia entre un método y otro es *cómo* se resuelve $\nabla S_r = \mathbf{0}$:
#
# | modelo | $\nabla S_r = \mathbf{0}$ es... | cómo se resuelve |
# |---|---|---|
# | lineal en $a_k$ | un sistema **lineal** ($Z^TZ\,\mathbf a = Z^T\mathbf y$) | solución directa (**Unidad 2**) |
# | no lineal | un sistema **no lineal** | métodos iterativos (**Unidad 6**) |

# %% [markdown]
# > Que el caso lineal tenga solución cerrada no es la regla general: es **la excepción afortunada**. Las ecuaciones normales no son otra cosa que $\nabla S_r=\mathbf{0}$ escrito para un modelo lineal.

# %% [markdown]
# Y los dos métodos iterativos que vimos son, literalmente, técnicas de búsqueda de raíces aplicadas a esa misma ecuación:
#
# | método | qué es |
# |---|---|
# | $\mathbf{a}_{k+1} = \mathbf{a}_k - \eta\,\nabla S_r(\mathbf{a}_k)$ | **iteración de punto fijo**: sus puntos fijos son las raíces de $\nabla S_r$ |
# | Gauss–Newton / Levenberg–Marquardt (`curve_fit`) | **método de Newton** sobre $\nabla S_r = \mathbf{0}$ |

# %% [markdown]
# > Por eso `curve_fit` pide un punto inicial (`p0`) y puede converger a una solución local: son los mismos riesgos de cualquier método de búsqueda de raíces no lineal (**Unidad 6**).

# %% [markdown]
# > **Cuidado:** $\nabla S_r = \mathbf{0}$ es condición *necesaria*, no suficiente: también la cumplen máximos y puntos de silla. Para un modelo lineal $S_r$ es un paraboloide y el único punto crítico es el mínimo global; en el caso no lineal, hay que verificar.

# %% [markdown]
# En síntesis
# <img src="./images/mapa_unidad3.png" width="860" align= center>

# %% [markdown]
# ### El riesgo: minimizar el error no es entender
# Ya lo vimos con `polyfit`: el método optimiza $r^2$, no la física. Llevemos la idea al extremo aumentando el grado del polinomio:

# %%
HTML(Path('interactive/A3_sobreajuste.html').read_text(encoding='utf-8'))
# Out:
# <meta charset="utf-8">
# <style>
# #sbr-app{--sbr-tinta:#1a2733; --sbr-suave:#5d6b78; --sbr-linea:#d8dee4; --sbr-panel:#f6f8fa;
#          --sbr-c1:#1f77b4; --sbr-c2:#ff7f0e; --sbr-rojo:#d62728; --sbr-acento:#00afd8;
#          --sbr-verde:#1c7a3e;
#          width:100%; max-width:min(808px, 94vw); margin:0; padding:4px 2px;
#          color:var(--sbr-tinta); background:transparent;
#          font-family:"Segoe UI",Calibri,system-ui,sans-serif; font-size:15px; line-height:1.45}
# #sbr-app *{box-sizing:border-box}
# #sbr-app .sbr-wrap{display:flex;gap:1.05em;align-items:flex-start;flex-wrap:wrap}
# #sbr-app .sbr-izq{flex:3 1 264px;min-width:0;max-width:448px}
# #sbr-app .sbr-der{flex:2 1 250px;min-width:0;font-size:0.85em}
# #sbr-app svg{width:100%;height:auto;display:block;background:#fff;
#              border:1px solid var(--sbr-linea);border-radius:0.55em}
# #sbr-app .sbr-ctrl{background:var(--sbr-panel);border:1px solid var(--sbr-linea);
# ...

# %% [markdown]
# > Un buen modelo no es el que mejor ajusta los datos que ya vio, sino el que **generaliza** a datos nuevos. En *machine learning* esto se llama **sobreajuste**, y es la razón por la que los datos se separan en *entrenamiento* y *validación*. Es la misma lógica del contraste ajuste vs. interpolación (Unidad 4).

# %% [markdown]
# **¿Qué herramienta uso?**
#
# | situación | herramienta |
# |---|---|
# | polinomio univariable | `numpy.polyfit` |
# | modelo lineal en los coeficientes (multivariable, bases generales) | `numpy.linalg.lstsq` |
# | modelo no lineal | `scipy.optimize.curve_fit` |

# %% [markdown]
# > Por ser iterativo, `curve_fit` puede requerir valores iniciales (`p0`) y converger a mínimos locales: úsenlo **exclusivamente cuando el modelo es realmente no lineal**. Para modelos lineales, la solución directa es exacta y estable.

# %% [markdown]
# ## Referencias
# - Kong Q., Siauw T., Bayen A. M. **Chapter 16: Least Square Regression** in *[Python Programming and Numerical Methods – A Guide for Engineers and Scientists](https://pythonnumericalmethods.berkeley.edu/notebooks/Index.html)*, 1st Ed., Academic Press, 2021
#
# - Chapra S., Canale R. **Capítulo 17: Regresión por mínimos cuadrados** en *Métodos Numéricos para Ingenieros*, 6ta Ed., McGraw Hill, 2011
#
# - Press W. H., Teukolsky S. A., Vetterling W. T., Flannery B. P. **Chapter 15: Modeling of Data** en *Numerical Recipes: The Art of Scientific Computing*, 3rd Ed., Cambridge University Press, 2007
